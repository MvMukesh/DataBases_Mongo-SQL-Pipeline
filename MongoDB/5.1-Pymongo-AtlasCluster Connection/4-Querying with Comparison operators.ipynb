# %% [markdown]
# ---
# # `Querying using Comparison Operators`
#
# ---

# %% [markdown]
# [Comparison operators](https://docs.mongodb.com/manual/reference/operator/query/#comparison) :- For comparison of different field values.
#
# - [$eq](https://docs.mongodb.com/manual/reference/operator/query/eq/#mongodb-query-op.-eq) - Matches values that are equal to a specified value.
#
# - [$ne](https://docs.mongodb.com/manual/reference/operator/query/ne/#mongodb-query-op.-ne) - Matches all values that are not equal to a specified value.
#
# - [$gt](https://docs.mongodb.com/manual/reference/operator/query/gt/#mongodb-query-op.-gt) - Matches values that are greater than a specified value.
#
# - [$gte](https://docs.mongodb.com/manual/reference/operator/query/gte/#mongodb-query-op.-gte) - Matches values that are greater than or equal to a specified value.
#
# - [$lt](https://docs.mongodb.com/manual/reference/operator/query/lt/#mongodb-query-op.-lt) - Matches values that are less than a specified value.
#
# - [$lte](https://docs.mongodb.com/manual/reference/operator/query/lte/#mongodb-query-op.-lte) - Matches values that are less than or equal to a specified value.
#
# - [$in](https://docs.mongodb.com/manual/reference/operator/query/in/#mongodb-query-op.-in) - Matches any of the values specified in an array.
#
# - [$nin](https://docs.mongodb.com/manual/reference/operator/query/nin/#mongodb-query-op.-nin) - Matches none of the values specified in an array.
#
# **Syntax of querying** - `{<field> : {<comparison_operator> : <value>}}`
#
#
# ---
# ----
# ### Connecting to MongoDB
#
# ----

# %%
import pymongo
import pprint as pp

# Does not allow pprint to sort the fields (this way we can see field wat they were inserted)
pp.sorted = lambda x, key=None: x

# %%
# Connect to the mongo client - Atlas Cluster
# client = pymongo.MongoClient('<connection_string>')

# %%
## Connect to local MongoDB server
# client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# Choose a database
db = client.sample_analytics

# %%
# Sample document
db.accounts.find_one()
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238c'),
#  'account_id': 371138,
#  'limit': 9000,
#  'products': ['Derivatives', 'InvestmentStock']}

# %% [markdown]
# ---
# **`$eq` operator**
#
# `$eq` operator matches values equal to specified value.
#
# For example,
# * retrieve documents where `limit` is 10000.
#
# ----

# %%
# Document where 'limit' is 10000
pp.pprint(
    db.accounts.find_one({
                            'limit':{'$eq':10000}
                         })
)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238d'),
#  'account_id': 557378,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'CurrencyService']}

# %% [markdown]
# ---
# * By default query Executes using `$eq` operator
#
# ---

# %%
# Document where 'limit' is 1000 
pp.pprint(
    db.accounts.find_one({
                            'limit':10000
                        })
)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238d'),
#  'account_id': 557378,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'CurrencyService']}

# %% [markdown]
# ---
# **`$lt` operator**
#
# Matches values that are less than a specified value
#
# For example,
# * Retrieve documents where `limit` < 10000 using `$lt`
#
# ---

# %%
# Document where 'limit' < 10000
pp.pprint(
    db.accounts.find_one({
                            'limit':{'$lt':10000}
                        })
)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238c'),
#  'account_id': 371138,
#  'limit': 9000,
#  'products': ['Derivatives', 'InvestmentStock']}

# %% [markdown]
# ----
# **`$ne` operator**
#
# Matches all values that are not equal to a specified value
#
# For example,
# * Retrieve all documents where `limit` is not equal to 7000 using `$ne`
#
# ---

# %%
# Document where 'limit' is not equal to 7000
cur = db.accounts.find({
                            'limit':{'$ne':7000}
                       })

for doc in cur:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238c'),
#  'account_id': 371138,
#  'limit': 9000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238d'),
#  'account_id': 557378,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238e'),
#  'account_id': 198100,
#  'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238f'),
#  'account_id': 674364,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162390'),
#  'account_id': 278603,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162391'),
#  'account_id': 383777,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162392'),
#  'account_id': 794875,
#  'limit': 9000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162393'),
#  'account_id': 328304,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162394'),
#  'account_id': 487188,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162395'),
#  'account_id': 910579,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162396'),
#  'account_id': 260499,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162397'),
#  'account_id': 668949,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162398'),
#  'account_id': 976027,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162399'),
#  'account_id': 135185,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816239a'),
#  'account_id': 370583,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816239b'),
#  'account_id': 870466,
#  'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816239c'),
#  'account_id': 692278,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816239d'),
#  'account_id': 864905,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816239e'),
#  'account_id': 299072,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816239f'),
#  'account_id': 137994,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a0'),
#  'account_id': 572981,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a1'),
#  'account_id': 977982,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'InvestmentStock',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a2'),
#  'account_id': 616040,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a3'),
#  'account_id': 775273,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a4'),
#  'account_id': 212024,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a5'),
#  'account_id': 433811,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a6'),
#  'account_id': 353465,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a7'),
#  'account_id': 464470,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a9'),
#  'account_id': 324287,
#  'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623aa'),
#  'account_id': 403363,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ac'),
#  'account_id': 276528,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ad'),
#  'account_id': 383701,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ae'),
#  'account_id': 423171,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623af'),
#  'account_id': 491860,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b0'),
#  'account_id': 463155,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b1'),
#  'account_id': 729049,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b2'),
#  'account_id': 209363,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b3'),
#  'account_id': 895735,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b4'),
#  'account_id': 996263,
#  'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b5'),
#  'account_id': 984021,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b6'),
#  'account_id': 503933,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b7'),
#  'account_id': 599752,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b8'),
#  'account_id': 475387,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b9'),
#  'account_id': 775690,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ba'),
#  'account_id': 813016,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623bb'),
#  'account_id': 136137,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623bc'),
#  'account_id': 831097,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623bd'),
#  'account_id': 918103,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623be'),
#  'account_id': 658755,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623bf'),
#  'account_id': 304914,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c0'),
#  'account_id': 522933,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c1'),
#  'account_id': 788678,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c2'),
#  'account_id': 827328,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c3'),
#  'account_id': 358213,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c4'),
#  'account_id': 595194,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c5'),
#  'account_id': 781775,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c6'),
#  'account_id': 375872,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c7'),
#  'account_id': 785786,
#  'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c8'),
#  'account_id': 462501,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c9'),
#  'account_id': 228290,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ca'),
#  'account_id': 968786,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Derivatives', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623cb'),
#  'account_id': 515844,
#  'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623cc'),
#  'account_id': 719065,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623cd'),
#  'account_id': 627629,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ce'),
#  'account_id': 55958,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623cf'),
#  'account_id': 771641,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Brokerage', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d0'),
#  'account_id': 604732,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d1'),
#  'account_id': 914559,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d2'),
#  'account_id': 721914,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d3'),
#  'account_id': 817222,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d4'),
#  'account_id': 973067,
#  'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d5'),
#  'account_id': 260799,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d6'),
#  'account_id': 87389,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d7'),
#  'account_id': 236908,
#  'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d8'),
#  'account_id': 696619,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d9'),
#  'account_id': 714727,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623da'),
#  'account_id': 969957,
#  'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623db'),
#  'account_id': 702610,
#  'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623dc'),
#  'account_id': 240640,
#  'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623dd'),
#  'account_id': 330318,
#  'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623de'),
#  'account_id': 571279,
#  'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623df'),
#  'account_id': 226398,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e0'),
#  'account_id': 161714,
#  'limit': 9000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e1'),
#  'account_id': 903542,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e2'),
#  'account_id': 472963,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e3'),
#  'account_id': 863889,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e4'),
#  'account_id': 344885,
#  'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e5'),
#  'account_id': 839927,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e6'),
#  'account_id': 853542,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e7'),
#  'account_id': 945232,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e8'),
#  'account_id': 278497,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e9'),
#  'account_id': 878471,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ea'),
#  'account_id': 720842,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623eb'),
#  'account_id': 394725,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ec'),
#  'account_id': 714030,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ed'),
#  'account_id': 443252,
#  'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ee'),
#  'account_id': 622916,
#  'limit': 9000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ef'),
#  'account_id': 53124,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f0'),
#  'account_id': 657243,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f1'),
#  'account_id': 475102,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f2'),
#  'account_id': 168924,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f3'),
#  'account_id': 858473,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f4'),
#  'account_id': 827843,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f5'),
#  'account_id': 644552,
#  'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f6'),
#  'account_id': 682405,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f7'),
#  'account_id': 299100,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f8'),
#  'account_id': 166084,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f9'),
#  'account_id': 664679,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623fa'),
#  'account_id': 452778,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623fb'),
#  'account_id': 126444,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623fc'),
#  'account_id': 702924,
#  'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623fd'),
#  'account_id': 165706,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623fe'),
#  'account_id': 328627,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162400'),
#  'account_id': 332179,
#  'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162401'),
#  'account_id': 831600,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162402'),
#  'account_id': 422649,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162403'),
#  'account_id': 556654,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162404'),
#  'account_id': 678107,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162405'),
#  'account_id': 855373,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162406'),
#  'account_id': 694827,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162407'),
#  'account_id': 199559,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162408'),
#  'account_id': 76399,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162409'),
#  'account_id': 159243,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816240a'),
#  'account_id': 275355,
#  'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816240b'),
#  'account_id': 832510,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816240c'),
#  'account_id': 329562,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816240d'),
#  'account_id': 160912,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816240e'),
#  'account_id': 516700,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816240f'),
#  'account_id': 377923,
#  'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162410'),
#  'account_id': 515170,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162411'),
#  'account_id': 378693,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162412'),
#  'account_id': 101383,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162413'),
#  'account_id': 588722,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162414'),
#  'account_id': 261796,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162415'),
#  'account_id': 387979,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162416'),
#  'account_id': 470650,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162417'),
#  'account_id': 443178,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162418'),
#  'account_id': 785350,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162419'),
#  'account_id': 931314,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241a'),
#  'account_id': 300405,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241b'),
#  'account_id': 59715,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241c'),
#  'account_id': 261248,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241d'),
#  'account_id': 451189,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241e'),
#  'account_id': 729536,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241f'),
#  'account_id': 723307,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162420'),
#  'account_id': 423254,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162421'),
#  'account_id': 118127,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162422'),
#  'account_id': 255695,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162423'),
#  'account_id': 581161,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162424'),
#  'account_id': 98267,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162425'),
#  'account_id': 637895,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162426'),
#  'account_id': 446747,
#  'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162427'),
#  'account_id': 838304,
#  'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162428'),
#  'account_id': 139582,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162429'),
#  'account_id': 149440,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816242a'),
#  'account_id': 296866,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816242b'),
#  'account_id': 316726,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816242c'),
#  'account_id': 278866,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816242d'),
#  'account_id': 78388,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816242e'),
#  'account_id': 330961,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816242f'),
#  'account_id': 612356,
#  'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162430'),
#  'account_id': 126668,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162431'),
#  'account_id': 701440,
#  'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162432'),
#  'account_id': 842570,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162433'),
#  'account_id': 987988,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162434'),
#  'account_id': 839727,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162435'),
#  'account_id': 161460,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162436'),
#  'account_id': 740604,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162437'),
#  'account_id': 347313,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162438'),
#  'account_id': 795909,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162439'),
#  'account_id': 689102,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816243a'),
#  'account_id': 199962,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816243b'),
#  'account_id': 673123,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816243c'),
#  'account_id': 312052,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816243d'),
#  'account_id': 175894,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816243e'),
#  'account_id': 849766,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816243f'),
#  'account_id': 977774,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162440'),
#  'account_id': 893492,
#  'limit': 9000,
#  'products': ['Commodity', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162441'),
#  'account_id': 904434,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162442'),
#  'account_id': 139687,
#  'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162443'),
#  'account_id': 120556,
#  'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162444'),
#  'account_id': 767808,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162445'),
#  'account_id': 647189,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162446'),
#  'account_id': 357510,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162447'),
#  'account_id': 348352,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162448'),
#  'account_id': 999137,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162449'),
#  'account_id': 126833,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Commodity', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816244a'),
#  'account_id': 155475,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816244b'),
#  'account_id': 293516,
#  'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816244c'),
#  'account_id': 924182,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816244d'),
#  'account_id': 116508,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816244e'),
#  'account_id': 700899,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816244f'),
#  'account_id': 292314,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162450'),
#  'account_id': 202669,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162451'),
#  'account_id': 226865,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162452'),
#  'account_id': 604215,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162453'),
#  'account_id': 585158,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162454'),
#  'account_id': 377292,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162455'),
#  'account_id': 494443,
#  'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162456'),
#  'account_id': 170945,
#  'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162457'),
#  'account_id': 951849,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162459'),
#  'account_id': 130514,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245a'),
#  'account_id': 563516,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245b'),
#  'account_id': 346408,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245c'),
#  'account_id': 904260,
#  'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245d'),
#  'account_id': 565468,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245e'),
#  'account_id': 679236,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245f'),
#  'account_id': 985280,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162460'),
#  'account_id': 898675,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162461'),
#  'account_id': 839760,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162462'),
#  'account_id': 264514,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162463'),
#  'account_id': 356905,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162464'),
#  'account_id': 571311,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162465'),
#  'account_id': 323636,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162466'),
#  'account_id': 409325,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162467'),
#  'account_id': 859697,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162468'),
#  'account_id': 116390,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162469'),
#  'account_id': 385397,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816246a'),
#  'account_id': 337979,
#  'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816246b'),
#  'account_id': 325377,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816246c'),
#  'account_id': 304450,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816246d'),
#  'account_id': 792665,
#  'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816246e'),
#  'account_id': 719866,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816246f'),
#  'account_id': 921942,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162470'),
#  'account_id': 156715,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162471'),
#  'account_id': 616103,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162472'),
#  'account_id': 485390,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162473'),
#  'account_id': 892478,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162474'),
#  'account_id': 455317,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162475'),
#  'account_id': 165436,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162476'),
#  'account_id': 455365,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162477'),
#  'account_id': 244662,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162478'),
#  'account_id': 120472,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162479'),
#  'account_id': 176639,
#  'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816247b'),
#  'account_id': 537968,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816247c'),
#  'account_id': 141597,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816247d'),
#  'account_id': 782938,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816247e'),
#  'account_id': 103536,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816247f'),
#  'account_id': 584846,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162480'),
#  'account_id': 456867,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162481'),
#  'account_id': 364643,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162482'),
#  'account_id': 716662,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162483'),
#  'account_id': 155111,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162484'),
#  'account_id': 969775,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162485'),
#  'account_id': 879238,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162486'),
#  'account_id': 199711,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162487'),
#  'account_id': 922402,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162488'),
#  'account_id': 130717,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162489'),
#  'account_id': 59768,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816248a'),
#  'account_id': 55104,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816248b'),
#  'account_id': 740050,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816248c'),
#  'account_id': 677943,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816248d'),
#  'account_id': 54368,
#  'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816248e'),
#  'account_id': 840171,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816248f'),
#  'account_id': 447644,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162490'),
#  'account_id': 469336,
#  'limit': 9000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162491'),
#  'account_id': 440243,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162492'),
#  'account_id': 586395,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162493'),
#  'account_id': 86702,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162494'),
#  'account_id': 786406,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162495'),
#  'account_id': 62872,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162496'),
#  'account_id': 327942,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162497'),
#  'account_id': 720370,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162498'),
#  'account_id': 358133,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162499'),
#  'account_id': 54977,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249a'),
#  'account_id': 951500,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249b'),
#  'account_id': 162007,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249c'),
#  'account_id': 737334,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'InvestmentFund', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249d'),
#  'account_id': 509894,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249e'),
#  'account_id': 433314,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249f'),
#  'account_id': 630581,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a0'),
#  'account_id': 733789,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a1'),
#  'account_id': 851281,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a2'),
#  'account_id': 987709,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a3'),
#  'account_id': 662207,
#  'limit': 9000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a4'),
#  'account_id': 816481,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a5'),
#  'account_id': 631901,
#  'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a6'),
#  'account_id': 200611,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a7'),
#  'account_id': 528224,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a8'),
#  'account_id': 931483,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a9'),
#  'account_id': 771691,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624aa'),
#  'account_id': 144469,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624ab'),
#  'account_id': 923468,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624ac'),
#  'account_id': 88112,
#  'limit': 9000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624ad'),
#  'account_id': 567199,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624ae'),
#  'account_id': 359211,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624af'),
#  'account_id': 436071,
#  'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b0'),
#  'account_id': 226641,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b1'),
#  'account_id': 660732,
#  'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b2'),
#  'account_id': 167939,
#  'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b3'),
#  'account_id': 185130,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b4'),
#  'account_id': 559866,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b5'),
#  'account_id': 205563,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b6'),
#  'account_id': 616602,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b7'),
#  'account_id': 387877,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b8'),
#  'account_id': 460069,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b9'),
#  'account_id': 448325,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Commodity', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624ba'),
#  'account_id': 666556,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624bb'),
#  'account_id': 66698,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624bc'),
#  'account_id': 859246,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624bd'),
#  'account_id': 183400,
#  'limit': 10000,
# ...
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629fe'),
#  'account_id': 323327,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629ff'),
#  'account_id': 462180,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a00'),
#  'account_id': 931602,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Brokerage', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a01'),
#  'account_id': 413410,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a02'),
#  'account_id': 679340,
#  'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a03'),
#  'account_id': 146967,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Commodity', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a04'),
#  'account_id': 596107,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'InvestmentFund', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a05'),
#  'account_id': 225511,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a06'),
#  'account_id': 437245,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a07'),
#  'account_id': 120917,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a08'),
#  'account_id': 272399,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a09'),
#  'account_id': 678737,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a0a'),
#  'account_id': 481744,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a0b'),
#  'account_id': 96021,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a0c'),
#  'account_id': 469791,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a0d'),
#  'account_id': 73934,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a0e'),
#  'account_id': 539248,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a0f'),
#  'account_id': 533671,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a10'),
#  'account_id': 390126,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a11'),
#  'account_id': 314671,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a12'),
#  'account_id': 718678,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a13'),
#  'account_id': 384574,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a14'),
#  'account_id': 546681,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a15'),
#  'account_id': 249810,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a16'),
#  'account_id': 633806,
#  'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a17'),
#  'account_id': 371264,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a18'),
#  'account_id': 307731,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a19'),
#  'account_id': 943710,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a1a'),
#  'account_id': 420660,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a1b'),
#  'account_id': 816560,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a1c'),
#  'account_id': 825051,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a1d'),
#  'account_id': 181687,
#  'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a1e'),
#  'account_id': 232492,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a1f'),
#  'account_id': 135875,
#  'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a20'),
#  'account_id': 380860,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a21'),
#  'account_id': 893845,
#  'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a22'),
#  'account_id': 643169,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a23'),
#  'account_id': 171129,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a24'),
#  'account_id': 212417,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a25'),
#  'account_id': 255004,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a26'),
#  'account_id': 352837,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a27'),
#  'account_id': 87286,
#  'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a28'),
#  'account_id': 657218,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a29'),
#  'account_id': 380304,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a2a'),
#  'account_id': 886274,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a2b'),
#  'account_id': 211212,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a2c'),
#  'account_id': 813925,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a2d'),
#  'account_id': 415745,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a2e'),
#  'account_id': 784910,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a2f'),
#  'account_id': 706316,
#  'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a30'),
#  'account_id': 311880,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a31'),
#  'account_id': 675631,
#  'limit': 8000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a32'),
#  'account_id': 881765,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a33'),
#  'account_id': 429071,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a34'),
#  'account_id': 423510,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a35'),
#  'account_id': 223693,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a36'),
#  'account_id': 222061,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a37'),
#  'account_id': 509384,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a38'),
#  'account_id': 867364,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a39'),
#  'account_id': 450464,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a3a'),
#  'account_id': 218101,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a3b'),
#  'account_id': 157495,
#  'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a3c'),
#  'account_id': 313907,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a3d'),
#  'account_id': 896364,
#  'limit': 9000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a3e'),
#  'account_id': 736396,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a3f'),
#  'account_id': 410867,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a40'),
#  'account_id': 508146,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a41'),
#  'account_id': 409978,
#  'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a42'),
#  'account_id': 646815,
#  'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a43'),
#  'account_id': 109710,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a44'),
#  'account_id': 669413,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a45'),
#  'account_id': 70492,
#  'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Brokerage', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a46'),
#  'account_id': 916567,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a47'),
#  'account_id': 327916,
#  'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a48'),
#  'account_id': 716494,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a49'),
#  'account_id': 142442,
#  'limit': 9000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a4a'),
#  'account_id': 989774,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a4b'),
#  'account_id': 270514,
#  'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a4c'),
#  'account_id': 650729,
#  'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a4d'),
#  'account_id': 991663,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a4e'),
#  'account_id': 144876,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a4f'),
#  'account_id': 912504,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a50'),
#  'account_id': 406478,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a51'),
#  'account_id': 496316,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a52'),
#  'account_id': 138703,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a53'),
#  'account_id': 599670,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a54'),
#  'account_id': 397774,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a55'),
#  'account_id': 996624,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a56'),
#  'account_id': 309490,
#  'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a57'),
#  'account_id': 551774,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a58'),
#  'account_id': 225728,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a59'),
#  'account_id': 771935,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5a'),
#  'account_id': 963591,
#  'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5b'),
#  'account_id': 635650,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5c'),
#  'account_id': 89698,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5d'),
#  'account_id': 206062,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5e'),
#  'account_id': 684319,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5f'),
#  'account_id': 351063,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a60'),
#  'account_id': 291224,
#  'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock']}

# %% [markdown]
# ---
# **`$gte` and `$lte` operators**
#
# We can combine multiple operators into a query
#
# For example,
# * Retrieving a document where the between `7500 <= limit <= 8000` using `$gte` and `$lte` operators
#
# ---

# %%
# Document where 7500 <='limit' <= 8000
pp.pprint(
    db.accounts.find_one({
                            'limit':{
                                        '$gte':7500, 
                                        "$lte":8000
                                    }
                        })
)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624d5'),
#  'account_id': 312740,
#  'limit': 8000,
#  'products': ['CurrencyService', 'InvestmentStock']}

# %% [markdown]
# ---
# **`$in` operator**
#
# `$in` operator matches any of the values specified in an array
#
# For example,
# * Retrieve documents where `limit` is either 3000 or 5000. It acts like a logical OR on the field
#
#
# ---

# %%
# Document where `limit` is either 3000 or 5000.

cur = db.accounts.find(
                        # query expression
                        {
                            # limit is either 3000 or 5000
                            "limit":{
                                            "$in": [3000, 5000]
                                    }
                        },
                        # projection
                        {
                            'limit':1
                        })

for doc in cur:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162661'), 'limit': 3000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626ad'), 'limit': 3000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816272e'), 'limit': 5000}

# %% [markdown]
# ---
# For example,
# * Retrieve a document where `5000 <= limit <= 8000` and `products` array field contains either `Commodity` or `Brokerage` elements
#
# ----

# %%
# Document where 5000 <='limit' <= 8000 and 
# 'products' contains either 'Commodity' or 'Brokerage'

pp.pprint(
    db.accounts.find_one({
                            # 5000<= limit <=8000
                            'limit':{
                                        '$gte':5000, 
                                        "$lte":8000
                                    }, 
                            # products contains either Commodity or Brokerage
                            "products":{
                                            "$in": ["Commodity", "Brokerage"]
                                        }
                        })
)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162458'),
#  'account_id': 852986,
#  'limit': 7000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}

# %% [markdown]
# ---
# **`$nin` operator**
#
# `$nin` operator is used to match **none** of the values within the provided array
#
# For example,
# * Retrieve documents where the `limit` is neither 9000 nor 10000
#
# ---

# %%
# Document where `limit` is neither 9000 or 10000.

cur = db.accounts.find(
                        # query expression
                        {
                            # limit is neither 9000 or 10000
                            "limit":{
                                            "$nin": [9000, 10000]
                                    }
                        },
                        # projection
                        {
                            'limit':1
                        })

for doc in cur:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162458'), 'limit': 7000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816247a'), 'limit': 7000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624d5'), 'limit': 8000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162530'), 'limit': 7000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162540'), 'limit': 8000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162565'), 'limit': 7000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162587'), 'limit': 8000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625ad'), 'limit': 7000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816264b'), 'limit': 8000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162661'), 'limit': 3000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626ad'), 'limit': 3000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816272e'), 'limit': 5000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816288f'), 'limit': 8000}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a31'), 'limit': 8000}

# %% [markdown]
# ---
# For example,
# * Retrieve a document where the `products` array field contains neither `Commodity` or `Brokerage` elements and `5000<=limit<=8000`
#
# ----

# %%
# Document where 5000 <='limit' <= 8000 and 
# 'products' contains neither 'Commodity' nor 'Brokerage'

pp.pprint(
    db.accounts.find_one({
                            # 5000<= limit <=8000
                            'limit':{
                                        '$gte':5000, 
                                        "$lte":8000
                                    },
                            # products contains neither Commodity or Brokerage
                            "products":{
                                            "$nin": ["Commodity", "Brokerage"]
                                        }
                        })
)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624d5'),
#  'account_id': 312740,
#  'limit': 8000,
#  'products': ['CurrencyService', 'InvestmentStock']}

# %% [markdown]
# ---
# # `Querying date fields`
#
# Querying on Date field as well

# %%
# Sample document
pp.pprint(
    db.customers.find_one()
)
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a68'),
#  'username': 'fmiller',
#  'name': 'Elizabeth Ray',
#  'address': '9286 Bethany Glens\nVasqueztown, CO 22939',
#  'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31),
#  'email': 'arroyocolton@gmail.com',
#  'active': True,
#  'accounts': [371138, 324287, 276528, 332179, 422649, 387979],
#  'tier_and_details': {'0df078f33aa74a2e9696e0520c1a828a': {'tier': 'Bronze',
#                                                            'id': '0df078f33aa74a2e9696e0520c1a828a',
#                                                            'active': True,
#                                                            'benefits': ['sports '
#                                                                         'tickets']},
#                       '699456451cc24f028d2aa99d7534c219': {'tier': 'Bronze',
#                                                            'benefits': ['24 '
#                                                                         'hour '
#                                                                         'dedicated '
#                                                                         'line',
#                                                                         'concierge '
#                                                                         'services'],
#                                                            'active': True,
#                                                            'id': '699456451cc24f028d2aa99d7534c219'}}}

# %% [markdown]
# ---
# Need the `datetime` library in Python to manipulate the data in Pymongo.
#
# ----

# %%
# Import datetime library
from datetime import datetime

# %% [markdown]
# ---
# * Look for all documents where `birthdate` is after `01.01.1995`
#
# ---

# %%
# Query
cur = db.customers.find(
                        # query expression
                        {
                            'birthdate': {
                                            '$gt': datetime(1995, 1, 1)
                                        }
                        },
                        # project (nead to see only birthdate and _id field is supressed)
                        {
                            'birthdate': 1,
                            '_id': 0
                        })

# Print result
for doc in cur:
    pp.pprint(doc)
# Out:
# {'birthdate': datetime.datetime(1996, 9, 13, 17, 14, 27)}
# {'birthdate': datetime.datetime(1995, 8, 11, 10, 46, 45)}
# {'birthdate': datetime.datetime(1995, 6, 1, 4, 23, 7)}
# {'birthdate': datetime.datetime(1995, 7, 1, 10, 40, 18)}
# {'birthdate': datetime.datetime(1996, 2, 23, 15, 35, 36)}
# {'birthdate': datetime.datetime(1996, 8, 27, 22, 56, 52)}
# {'birthdate': datetime.datetime(1995, 11, 10, 14, 58, 16)}
# {'birthdate': datetime.datetime(1996, 3, 14, 23, 23, 36)}
# {'birthdate': datetime.datetime(1995, 12, 29, 3, 37, 46)}
# {'birthdate': datetime.datetime(1995, 10, 16, 16, 24, 5)}
# {'birthdate': datetime.datetime(1996, 8, 12, 11, 56, 44)}
# {'birthdate': datetime.datetime(1995, 5, 14, 14, 52, 23)}
# {'birthdate': datetime.datetime(1996, 1, 17, 7, 32, 33)}
# {'birthdate': datetime.datetime(1995, 10, 23, 8, 50, 37)}
# {'birthdate': datetime.datetime(1995, 8, 19, 4, 19, 15)}
# {'birthdate': datetime.datetime(1996, 6, 4, 10, 46, 29)}
# {'birthdate': datetime.datetime(1996, 4, 10, 3, 22, 48)}
# {'birthdate': datetime.datetime(1995, 1, 16, 7, 43, 27)}
# {'birthdate': datetime.datetime(1997, 4, 11, 6, 31, 30)}
# {'birthdate': datetime.datetime(1995, 9, 20, 20, 33, 46)}
# {'birthdate': datetime.datetime(1996, 7, 5, 3, 28, 51)}
# {'birthdate': datetime.datetime(1996, 3, 3, 1, 13, 50)}
# {'birthdate': datetime.datetime(1995, 4, 18, 7, 22, 11)}
# {'birthdate': datetime.datetime(1995, 9, 4, 17, 0, 11)}
# {'birthdate': datetime.datetime(1995, 3, 9, 2, 25, 2)}
# {'birthdate': datetime.datetime(1996, 5, 2, 5, 39, 26)}
# {'birthdate': datetime.datetime(1996, 11, 29, 14, 23, 25)}
# {'birthdate': datetime.datetime(1995, 5, 24, 13, 38, 46)}
# {'birthdate': datetime.datetime(1996, 3, 28, 20, 42, 14)}
# {'birthdate': datetime.datetime(1996, 9, 24, 16, 52, 15)}
# {'birthdate': datetime.datetime(1996, 5, 4, 1, 21, 7)}
# {'birthdate': datetime.datetime(1995, 9, 15, 1, 10, 12)}
# {'birthdate': datetime.datetime(1996, 1, 19, 10, 26, 9)}
# {'birthdate': datetime.datetime(1995, 7, 18, 7, 21, 10)}
# {'birthdate': datetime.datetime(1997, 2, 16, 18, 3, 39)}
# {'birthdate': datetime.datetime(1997, 3, 25, 9, 57, 22)}
# {'birthdate': datetime.datetime(1996, 6, 27, 6, 51, 35)}
# {'birthdate': datetime.datetime(1997, 3, 5, 18, 20, 57)}

# %% [markdown]
# ---
# * All documents where birth year is in year 1995
#
# ---

# %%
# Query
cur = db.customers.find(
                        # query expression
                        {
                            'birthdate': {
                                            '$gte': datetime(1995, 1, 1),
                                            '$lt': datetime(1996, 1, 1)
                                        }
                        },
                        # project
                        {
                            'birthdate': 1,
                            '_id': 0
                        })

# Print result
for doc in cur:
    pp.pprint(doc)
# Out:
# {'birthdate': datetime.datetime(1995, 8, 11, 10, 46, 45)}
# {'birthdate': datetime.datetime(1995, 6, 1, 4, 23, 7)}
# {'birthdate': datetime.datetime(1995, 7, 1, 10, 40, 18)}
# {'birthdate': datetime.datetime(1995, 11, 10, 14, 58, 16)}
# {'birthdate': datetime.datetime(1995, 12, 29, 3, 37, 46)}
# {'birthdate': datetime.datetime(1995, 10, 16, 16, 24, 5)}
# {'birthdate': datetime.datetime(1995, 5, 14, 14, 52, 23)}
# {'birthdate': datetime.datetime(1995, 10, 23, 8, 50, 37)}
# {'birthdate': datetime.datetime(1995, 8, 19, 4, 19, 15)}
# {'birthdate': datetime.datetime(1995, 1, 16, 7, 43, 27)}
# {'birthdate': datetime.datetime(1995, 9, 20, 20, 33, 46)}
# {'birthdate': datetime.datetime(1995, 4, 18, 7, 22, 11)}
# {'birthdate': datetime.datetime(1995, 9, 4, 17, 0, 11)}
# {'birthdate': datetime.datetime(1995, 3, 9, 2, 25, 2)}
# {'birthdate': datetime.datetime(1995, 5, 24, 13, 38, 46)}
# {'birthdate': datetime.datetime(1995, 9, 15, 1, 10, 12)}
# {'birthdate': datetime.datetime(1995, 7, 18, 7, 21, 10)}

# %% [markdown]
# ---
# ### Question -
#
# * Find documents from `accounts` collection where `7000<= limit <= 9000` and `products` contains either `Derivatives, Commodity or Brokerage` elements?
#     * Print only `'limit` and `products` fields

# %%
# Question
cur = db.accounts.find(
                        # query expression
                        {
                            'limit':{
                                        '$gte': 5000,
                                        '$lte': 9000
                                    },
                            'products':{
                                        '$in': ['Brokerage', 
                                                'Commodity', 
                                                'Derivatives']
                                        }
                        },
                        # projection
                        {
                            'limit':1,
                            'products':1,
                            '_id':0
                        })

for doc in cur:
    pp.pprint(doc)
# Out:
# {'limit': 9000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 7000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 7000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'limit': 9000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 9000, 'products': ['CurrencyService', 'InvestmentStock', 'Commodity']}
# {'limit': 9000, 'products': ['Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 9000, 'products': ['Brokerage', 'InvestmentStock']}
# {'limit': 7000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 8000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 9000, 'products': ['Brokerage', 'InvestmentStock']}
# {'limit': 9000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 7000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'limit': 8000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 7000, 'products': ['InvestmentStock', 'Brokerage']}
# {'limit': 9000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 5000,
#  'products': ['InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 9000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 9000, 'products': ['InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 9000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000, 'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 8000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 9000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}

# %% [markdown]
# ---
# ### Question -
#
# * Retrieve only `birthdate` and `active` fields from documents from `customers` collection whose`birthdate` is before year `2000` and where `active` is `True`
#     * Sort documents by `birthdate` in ascending order

# %%
# Question
cur = db.customers.find(
                        # query expression
                        {
                            'birthdate': {
                                            '$lt': datetime(2000, 1, 1)
                                        },
                            'active':True
                        },
                        # project
                        {
                            'birthdate': 1,
                            'active':1,
                            '_id': 0
                        })\
                    .sort([('birthdate', pymongo.ASCENDING)])

for doc in cur:
    pp.pprint(doc)
# Out:
# {'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31), 'active': True}

# %% [markdown]
# ---
# ## Exercise 1 -
#
# * Count number of documents from `accounts` collection where either `limit <= 5000` and `products` contains neither `Derivatives, Commodity or Brokerage` elements

# %% [markdown]
# ---
# ## Exercise 2 -
#
# Have a look at a sample `transactions` collection document below
#
# * Count number of documents from `transactions` collection where `transaction_count` is more than 50 and `bucket_start_date` is before 1980

# %%
# Sample document
pp.pprint(
    db.transactions.find_one()
)
# Out:
# {'_id': ObjectId('5ca4bbc1a2dd94ee58161cb1'),
#  'account_id': 443178,
#  'transaction_count': 66,
#  'bucket_start_date': datetime.datetime(1969, 2, 4, 0, 0),
#  'bucket_end_date': datetime.datetime(2017, 1, 3, 0, 0),
#  'transactions': [{'date': datetime.datetime(2003, 9, 9, 0, 0),
#                    'amount': 7514,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '19.1072802650074180519368383102118968963623046875',
#                    'total': '143572.1039112657392422534031'},
#                   {'date': datetime.datetime(2016, 6, 14, 0, 0),
#                    'amount': 9240,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '24.1525632387771480580340721644461154937744140625',
#                    'total': '223169.6843263008480562348268'},
#                   {'date': datetime.datetime(2002, 12, 4, 0, 0),
#                    'amount': 2824,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.046193953245431629284212249331176280975341796875',
#                    'total': '59434.45172396509892109861539'},
#                   {'date': datetime.datetime(2014, 7, 14, 0, 0),
#                    'amount': 7418,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '76.38514540536692720706923864781856536865234375',
#                    'total': '566625.0086170118660220396123'},
#                   {'date': datetime.datetime(2011, 10, 28, 0, 0),
#                    'amount': 5638,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '28.365657608641175357888641883619129657745361328125',
#                    'total': '159925.5775975189466677761629'},
#                   {'date': datetime.datetime(2010, 12, 20, 0, 0),
#                    'amount': 6774,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '45.3237971108758159743956639431416988372802734375',
#                    'total': '307023.4016290727774105562276'},
#                   {'date': datetime.datetime(2015, 10, 28, 0, 0),
#                    'amount': 7251,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '102.936674838205050264150486327707767486572265625',
#                    'total': '746393.8292518248194653551764'},
#                   {'date': datetime.datetime(2012, 2, 2, 0, 0),
#                    'amount': 8828,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '17.838862313630283296106426860205829143524169921875',
#                    'total': '157481.4765047281409380275363'},
#                   {'date': datetime.datetime(2016, 3, 14, 0, 0),
#                    'amount': 5585,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '22.645934804740733170547173358500003814697265625',
#                    'total': '126477.5458844769947575059632'},
#                   {'date': datetime.datetime(2012, 3, 1, 0, 0),
#                    'amount': 5789,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '16.0804676963220600782733527012169361114501953125',
#                    'total': '93089.82749400840579312443879'},
#                   {'date': datetime.datetime(2001, 1, 4, 0, 0),
#                    'amount': 7856,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '26.71098408678698632456871564500033855438232421875',
#                    'total': '209841.4909857985645658118301'},
#                   {'date': datetime.datetime(2015, 12, 14, 0, 0),
#                    'amount': 8539,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '120.2002067302756387334738974459469318389892578125',
#                    'total': '1026389.565269823679145133610'},
#                   {'date': datetime.datetime(2016, 10, 5, 0, 0),
#                    'amount': 4967,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '90.35066753097771652392111718654632568359375',
#                    'total': '448771.7656263663179743161891'},
#                   {'date': datetime.datetime(2016, 9, 26, 0, 0),
#                    'amount': 2893,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '30.227075585186970130280315061099827289581298828125',
#                    'total': '87446.92966794590458690095147'},
#                   {'date': datetime.datetime(1992, 7, 17, 0, 0),
#                    'amount': 9559,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '19.83986843992497739463942707516252994537353515625',
#                    'total': '189649.3024172428589153582834'},
#                   {'date': datetime.datetime(1978, 2, 16, 0, 0),
#                    'amount': 8269,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '13.2722697458426655003904670593328773975372314453125',
#                    'total': '109748.3985283730010227287721'},
#                   {'date': datetime.datetime(2016, 6, 1, 0, 0),
#                    'amount': 8081,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '143.758609271150135100469924509525299072265625',
#                    'total': '1161713.321520164241746897460'},
#                   {'date': datetime.datetime(1986, 10, 23, 0, 0),
#                    'amount': 6145,
#                    'transaction_code': 'sell',
#                    'symbol': 'adbe',
#                    'price': '0.2800000011920928955078125',
#                    'total': '1720.600007325410842895507812'},
#                   {'date': datetime.datetime(2010, 10, 22, 0, 0),
#                    'amount': 6973,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '21.268423447276756377277706633321940898895263671875',
#                    'total': '148304.7166978608222187574484'},
#                   {'date': datetime.datetime(2016, 7, 28, 0, 0),
#                    'amount': 3082,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '86.029571359374330086211557500064373016357421875',
#                    'total': '265143.1389295916853257040202'},
#                   {'date': datetime.datetime(1988, 11, 18, 0, 0),
#                    'amount': 2978,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '0.2432200014591217041015625',
#                    'total': '724.3091643452644348144531250'},
#                   {'date': datetime.datetime(2002, 2, 20, 0, 0),
#                    'amount': 9265,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '81.091017566265037430639495141804218292236328125',
#                    'total': '751308.2777514455717948749225'},
#                   {'date': datetime.datetime(2014, 8, 18, 0, 0),
#                    'amount': 9192,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.557668636076840584792080335319042205810546875',
#                    'total': '685334.0901028183186554088024'},
#                   {'date': datetime.datetime(1971, 11, 17, 0, 0),
#                    'amount': 7408,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '12.4267172965691319319603280746378004550933837890625',
#                    'total': '92057.12173298412935196211038'},
#                   {'date': datetime.datetime(2011, 12, 23, 0, 0),
#                    'amount': 3267,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '10.54898647579047832323340117000043392181396484375',
#                    'total': '34463.53881640749268200352162'},
#                   {'date': datetime.datetime(2012, 5, 24, 0, 0),
#                    'amount': 7582,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '10.1614266582902761371087763109244406223297119140625',
#                    'total': '77043.93692315687367155874199'},
#                   {'date': datetime.datetime(2012, 8, 20, 0, 0),
#                    'amount': 643,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '9.1583720360888047906655629049055278301239013671875',
#                    'total': '5888.833219205101480397956948'},
#                   {'date': datetime.datetime(2013, 3, 27, 0, 0),
#                    'amount': 3129,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '74.33570821035419839972746558487415313720703125',
#                    'total': '232596.4309901982867927472398'},
#                   {'date': datetime.datetime(2015, 10, 22, 0, 0),
#                    'amount': 4075,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '45.37162592751771938992533250711858272552490234375',
#                    'total': '184889.3756546347065139457300'},
#                   {'date': datetime.datetime(2016, 7, 21, 0, 0),
#                    'amount': 4386,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '27.936906667695467376688611693680286407470703125',
#                    'total': '122531.2726445123199141562509'},
#                   {'date': datetime.datetime(1993, 12, 2, 0, 0),
#                    'amount': 3093,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '2.978981080777631351708123474963940680027008056640625',
#                    'total': '9213.988482845213770833225908'},
#                   {'date': datetime.datetime(2011, 6, 1, 0, 0),
#                    'amount': 5053,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '34.76661582629167668301306548528373241424560546875',
#                    'total': '175675.7097702518422792650199'},
#                   {'date': datetime.datetime(2010, 12, 1, 0, 0),
#                    'amount': 1428,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '28.3197718777616813667918904684484004974365234375',
#                    'total': '40440.63424144368099177881959'},
#                   {'date': datetime.datetime(2002, 2, 5, 0, 0),
#                    'amount': 7974,
#                    'transaction_code': 'sell',
#                    'symbol': 'msft',
#                    'price': '23.08480386999243449963614693842828273773193359375',
#                    'total': '184078.2260593196727000986357'},
#                   {'date': datetime.datetime(2016, 10, 13, 0, 0),
#                    'amount': 5363,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '27.9515663517458960996009409427642822265625',
#                    'total': '149904.2503444132407821598463'},
#                   {'date': datetime.datetime(2009, 4, 15, 0, 0),
#                    'amount': 4050,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '35.82050501072183834594397922046482563018798828125',
#                    'total': '145073.0452934234453010731158'},
#                   {'date': datetime.datetime(2013, 6, 28, 0, 0),
#                    'amount': 7447,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '165.427301038519743769938941113650798797607421875',
#                    'total': '1231937.110833856531854735294'},
#                   {'date': datetime.datetime(1983, 5, 16, 0, 0),
#                    'amount': 1586,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '23.801111434215950879433876252733170986175537109375',
#                    'total': '37748.56273466649809478212774'},
#                   {'date': datetime.datetime(2005, 3, 16, 0, 0),
#                    'amount': 7124,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '36.91652269537627262252499349415302276611328125',
#                    'total': '262993.3076818605661628680537'},
#                   {'date': datetime.datetime(1993, 3, 19, 0, 0),
#                    'amount': 2940,
#                    'transaction_code': 'sell',
#                    'symbol': 'ibm',
#                    'price': '11.3086767608907070581381049123592674732208251953125',
#                    'total': '33247.50967701867875092602844'},
#                   {'date': datetime.datetime(1993, 6, 18, 0, 0),
#                    'amount': 2273,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '4.16809173919640141292575208353810012340545654296875',
#                    'total': '9474.072523193420411580234486'},
#                   {'date': datetime.datetime(1994, 6, 28, 0, 0),
#                    'amount': 2342,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '12.5191271611065957358732703141868114471435546875',
#                    'total': '29319.79581131164721341519908'},
#                   {'date': datetime.datetime(2010, 9, 3, 0, 0),
#                    'amount': 6380,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '41.865973826467524077088455669581890106201171875',
#                    'total': '267104.9130128628036118243472'},
#                   {'date': datetime.datetime(1997, 9, 11, 0, 0),
#                    'amount': 9598,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '5.39232880197155584056645238888449966907501220703125',
#                    'total': '51755.57184132299295775681003'},
#                   {'date': datetime.datetime(2016, 3, 9, 0, 0),
#                    'amount': 4123,
#                    'transaction_code': 'sell',
#                    'symbol': 'sap',
#                    'price': '75.127503708197110654509742744266986846923828125',
#                    'total': '309750.6977888966872285436693'},
#                   {'date': datetime.datetime(2008, 4, 17, 0, 0),
#                    'amount': 2473,
#                    'transaction_code': 'buy',
#                    'symbol': 'sap',
#                    'price': '46.75625859046404997343415743671357631683349609375',
#                    'total': '115628.2274942175955843026713'},
#                   {'date': datetime.datetime(1979, 1, 11, 0, 0),
#                    'amount': 8901,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '16.159743422775360244258990860544145107269287109375',
#                    'total': '143837.8762061234815341492776'},
#                   {'date': datetime.datetime(2013, 1, 7, 0, 0),
#                    'amount': 2588,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '14.43803234005940083761743153445422649383544921875',
#                    'total': '37365.62769607372936775391281'},
#                   {'date': datetime.datetime(2003, 2, 19, 0, 0),
#                    'amount': 578,
#                    'transaction_code': 'sell',
#                    'symbol': 'adbe',
#                    'price': '14.1196581565672598657101843855343759059906005859375',
#                    'total': '8161.162414495876202380486575'},
#                   {'date': datetime.datetime(1982, 7, 22, 0, 0),
#                    'amount': 964,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '13.85120720985607789543792023323476314544677734375',
#                    'total': '13352.56375030125909120215510'},
#                   {'date': datetime.datetime(2016, 12, 8, 0, 0),
#                    'amount': 3970,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '26.247716617401248839769323240034282207489013671875',
#                    'total': '104203.4349710829578938842133'},
#                   {'date': datetime.datetime(2015, 9, 3, 0, 0),
#                    'amount': 6607,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '79.33405532799093862195149995386600494384765625',
#                    'total': '524160.1035520361314752335602'},
#                   {'date': datetime.datetime(2015, 12, 22, 0, 0),
#                    'amount': 4221,
#                    'transaction_code': 'sell',
#                    'symbol': 'team',
#                    'price': '30.4044667242776398552450700663030147552490234375',
#                    'total': '128337.2540431759178289894407'},
#                   {'date': datetime.datetime(2008, 8, 19, 0, 0),
#                    'amount': 4799,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '43.96347030926532539751860895194113254547119140625',
#                    'total': '210980.6940141642965826918044'},
#                   {'date': datetime.datetime(1991, 5, 30, 0, 0),
#                    'amount': 4657,
#                    'transaction_code': 'sell',
#                    'symbol': 'msft',
#                    'price': '1.1517732225800922929437319908174686133861541748046875',
#                    'total': '5363.807897555489808238959881'},
#                   {'date': datetime.datetime(2014, 10, 6, 0, 0),
#                    'amount': 6397,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '66.439073760834702397914952598512172698974609375',
#                    'total': '425010.7548480595912394619518'},
#                   {'date': datetime.datetime(2007, 7, 11, 0, 0),
#                    'amount': 6352,
#                    'transaction_code': 'buy',
#                    'symbol': 'ibm',
#                    'price': '90.5944805618852484485614695586264133453369140625',
#                    'total': '575456.1405290950981452624546'},
#                   {'date': datetime.datetime(2008, 2, 20, 0, 0),
#                    'amount': 2800,
#                    'transaction_code': 'buy',
#                    'symbol': 'nflx',
#                    'price': '3.790661287329261330825147524592466652393341064453125',
#                    'total': '10613.85160452193172631041307'},
#                   {'date': datetime.datetime(2016, 1, 4, 0, 0),
#                    'amount': 1376,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '28.893855339485757127704346203245222568511962890625',
#                    'total': '39757.94494713240180772118038'},
#                   {'date': datetime.datetime(1989, 3, 16, 0, 0),
#                    'amount': 3044,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '1.2795149853767535663706667037331499159336090087890625',
#                    'total': '3894.843615486837856032309446'},
#                   {'date': datetime.datetime(1998, 6, 30, 0, 0),
#                    'amount': 7246,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '19.697308460376579120065798633731901645660400390625',
#                    'total': '142726.6971038886923039967769'},
#                   {'date': datetime.datetime(2014, 7, 7, 0, 0),
#                    'amount': 5935,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '38.65917577251284598105485201813280582427978515625',
#                    'total': '229442.2082098637408975605467'},
#                   {'date': datetime.datetime(2009, 9, 25, 0, 0),
#                    'amount': 4155,
#                    'transaction_code': 'buy',
#                    'symbol': 'adbe',
#                    'price': '32.28257057551964948061140603385865688323974609375',
#                    'total': '134134.0807412841435919403921'},
#                   {'date': datetime.datetime(2016, 6, 27, 0, 0),
#                    'amount': 5199,
#                    'transaction_code': 'buy',
#                    'symbol': 'team',
#                    'price': '25.54567484371674623844228335656225681304931640625',
#                    'total': '132811.9635124833636936614312'},
#                   {'date': datetime.datetime(2010, 4, 1, 0, 0),
#                    'amount': 9229,
#                    'transaction_code': 'sell',
#                    'symbol': 'nflx',
#                    'price': '10.6848136359437528852822651970200240612030029296875',
#                    'total': '98610.14504612489537827002550'},
#                   {'date': datetime.datetime(2005, 7, 7, 0, 0),
#                    'amount': 2881,
#                    'transaction_code': 'buy',
#                    'symbol': 'msft',
#                    'price': '20.6769287918292690164889791049063205718994140625',
#                    'total': '59570.23184926012403650474880'}]}
