# %% [markdown]
# # `Querying with Logical Operators`

# %% [markdown]
# [Logical operators](https://docs.mongodb.com/manual/reference/operator/query/#logical) :- Let you combine more than one expression to query.
#
#
# - [$and](https://docs.mongodb.com/manual/reference/operator/query/and/#mongodb-query-op.-and) = Joins query clauses with a logical AND.
#
# - [$or](https://docs.mongodb.com/manual/reference/operator/query/or/#mongodb-query-op.-or) = Joins query clauses with a logical OR.
#
# - [$nor](https://docs.mongodb.com/manual/reference/operator/query/nor/#mongodb-query-op.-nor) = Joins query clauses with a logical NOR.
#
# - [$not](https://docs.mongodb.com/manual/reference/operator/query/not/#mongodb-query-op.-not) = Inverts the effect of a query expression.
#
#
# **Syntax** : `{ <operator> : [ { <field1> : <value1> }, { <field2> : <value2> }, ... ] }`
#
# ---
#
# ## Connecting to MongoDB

# %%
# Importing the required libraries
import pymongo
import pprint as pp

pp.sorted = lambda x, key=None: x

# %%
# Connect to the mongo client - Atlas Cluster
# client = pymongo.MongoClient('<connection_string>')

# %%
## Connect to local MongoDB server
# client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# Choose a database
db = client.sample_analytics

# %%
# Sample document
db.accounts.find_one()
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238c'),
#  'account_id': 371138,
#  'limit': 9000,
#  'products': ['Derivatives', 'InvestmentStock']}

# %% [markdown]
# ---
# **`$and` operator**
#
# `$and` joins query clauses with a logical AND returns all documents that match the conditions of both clauses.
#
# For example,
# * using [$and](https://docs.mongodb.com/manual/reference/operator/query/and/#op._S_and) to find documents where `limit` is `10000` and `products` contains `Derivatives` element
#     * All expressions are to be provided in an array

# %%
# Documents where `limit` is `10000` and `products` contains the `Derivatives` element.

cur = db.accounts.find(
                        # query expression
                        {
                            '$and':[
                                        {'limit':10000},
                                        {'products':'Derivatives'}
                                    ]
                       },
                       # projection
                       {
                           'limit':1,
                            'products':1,
                            '_id':0
                       })

# Print documents

for doc in cur:
    pp.pprint(doc)
# Out:
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000, 'products': ['Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Brokerage', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'Derivatives',
#               'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'Derivatives',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'Derivatives',
#               'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock',
#               'Derivatives',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Brokerage',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'Commodity',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService', 'Brokerage']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Brokerage',
#               'Commodity',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Commodity', 'Derivatives']}
# ...
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Brokerage', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}

# %% [markdown]
# **`$and` operator is used by default when no operator is specified in query**
#
# For example,
# * Implementing above query without any operator

# %%
# Documents where `limit` is `10000` and `products` contains the `Derivatives` element.

cur = db.accounts.find(
                        {
                            'limit':10000, 
                            'products':'Derivatives'
                        },
                        {
                            'limit':1,
                            'products':1,
                            '_id':0
                        })

# Print documents

for doc in cur:
    pp.pprint(doc)
# Out:
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000, 'products': ['Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Brokerage', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'Derivatives',
#               'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'Derivatives',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'Derivatives',
#               'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock',
#               'Derivatives',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Brokerage',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'Commodity',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService', 'Brokerage']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Brokerage',
#               'Commodity',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Commodity', 'Derivatives']}
# ...
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Brokerage', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}

# %% [markdown]
# ---
# **Can combine them with other operators like `comparison operators` and `array operators`**
#
# For example,
# * Query to find Account that has `7000 < limit <= 9000` and contains `CurrencyService` and `InvestmentStock` as `products`

# %%
# Combining query operators 

cur = db.accounts.find(
                        # query expression
                        {
                            '$and':[
                                        {
                                            'limit':{
                                                        '$gt':7000, 
                                                        '$lte':9000
                                                    }
                                        },
                                        {
                                            'products':{
                                                            '$all':['CurrencyService',
                                                                    'InvestmentStock']
                                                        }
                                        }
                                    ]
                       },
                       # projection
                       {
                           'products':1,
                           'limit':1,
                           '_id':0
                       })

# Print all documents
for doc in cur:
    pp.pprint(doc)
# Out:
# {'limit': 9000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 9000, 'products': ['CurrencyService', 'InvestmentStock', 'Commodity']}
# {'limit': 8000, 'products': ['CurrencyService', 'InvestmentStock']}
# {'limit': 9000, 'products': ['CurrencyService', 'InvestmentStock']}
# {'limit': 9000, 'products': ['CurrencyService', 'InvestmentStock']}
# {'limit': 8000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000, 'products': ['CurrencyService', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000, 'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}

# %% [markdown]
# ---
#
# **`$or` operator**
#
# [$or](https://docs.mongodb.com/manual/reference/operator/query/or/#op._S_or) operator joins query clauses with a logical OR returns all documents that match conditions of either clause
#
# For example,
# * Retrieve documents where either `limit < 9000` or `products` contains either `Derivatives` or `Commodity`

# %%
# OR condition on multiple fields

cur = db.accounts.find(
                        # query expression
                        {
                            '$or':[
                                        # limit < 9000
                                        {
                                            'limit':{
                                                        '$lt':9000
                                                    }
                                        },
                                        # products has either 'Derivatives' or 'Commodity'
                                        {
                                            'products':{
                                                            '$in':['Derivatives',
                                                                   'Commodity']
                                                        }
                                        }
                                  ]
                       },
                       # projection
                       {
                           'products':1,
                           'limit':1,
                           '_id':0
                       })

# Print all documents

for doc in cur:
    pp.pprint(doc)
# Out:
# {'limit': 9000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Brokerage', 'CurrencyService']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 9000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 9000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 9000,
#  'products': ['Commodity', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 7000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 7000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService',
#               'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 9000, 'products': ['CurrencyService', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Commodity', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Brokerage', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 9000, 'products': ['Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock',
#               'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 8000, 'products': ['CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage', 'Commodity']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 7000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'Commodity',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Commodity']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 8000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 9000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Brokerage', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 7000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity', 'InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 8000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 7000, 'products': ['InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Commodity', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Commodity', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'CurrencyService', 'Brokerage']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'Brokerage']}
# {'limit': 8000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Commodity',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 3000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
# ...
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'Commodity', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock',
#               'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Derivatives', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives',
#               'InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives', 'Brokerage']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'Derivatives',
#               'Commodity',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund',
#               'Commodity']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund', 'Brokerage']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Brokerage',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 9000,
#  'products': ['InvestmentFund',
#               'Commodity',
#               'Derivatives',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'CurrencyService']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Commodity',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Brokerage', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Commodity', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'InvestmentFund',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Commodity',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage',
#               'Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Brokerage']}
# {'limit': 10000, 'products': ['Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 8000,
#  'products': ['Commodity', 'Derivatives', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService',
#               'Derivatives',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 9000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Brokerage', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'Derivatives',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Brokerage', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Brokerage', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 9000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'Derivatives',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'CurrencyService', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'Brokerage', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'Brokerage', 'InvestmentStock', 'CurrencyService']}
# {'limit': 10000,
#  'products': ['Commodity', 'CurrencyService', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}

# %% [markdown]
# ----
# **Multiple logical operators**
#
# For example,
# * Here we have `customers` collection

# %%
pp.pprint(
    db.customers.find_one()
)
# Out:
# {'_id': ObjectId('5ca4bbcea2dd94ee58162a68'),
#  'username': 'fmiller',
#  'name': 'Elizabeth Ray',
#  'address': '9286 Bethany Glens\nVasqueztown, CO 22939',
#  'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31),
#  'email': 'arroyocolton@gmail.com',
#  'active': True,
#  'accounts': [371138, 324287, 276528, 332179, 422649, 387979],
#  'tier_and_details': {'0df078f33aa74a2e9696e0520c1a828a': {'tier': 'Bronze',
#                                                            'id': '0df078f33aa74a2e9696e0520c1a828a',
#                                                            'active': True,
#                                                            'benefits': ['sports '
#                                                                         'tickets']},
#                       '699456451cc24f028d2aa99d7534c219': {'tier': 'Bronze',
#                                                            'benefits': ['24 '
#                                                                         'hour '
#                                                                         'dedicated '
#                                                                         'line',
#                                                                         'concierge '
#                                                                         'services'],
#                                                            'active': True,
#                                                            'id': '699456451cc24f028d2aa99d7534c219'}}}

# %% [markdown]
# ---
# * Retrieve all documents where
#     * either `birthdate` is before (1996,1,1) and `active` is True,or `birthdate` is on and after (1996,1,1) and `active` is False

# %%
# Import datetime library
from datetime import datetime

# %%
# Query
cur = db.customers.find(
            # query expression  
            {
                  '$or':[
                             # birthdate before (1996,1,1) and active
                             {
                                 '$and':[
                                          {'birthdate':{'$lt':datetime(1996, 1, 1)}},
                                          {'active': True}
                                        ]
                             },
                             # birthdate after (1996,1,1) and not active
                             {
                                 '$and':[
                                          {'birthdate':{'$gte':datetime(1996, 1, 1)}},
                                          {'active': False}
                                        ]
                             }
                      ]
              },
             # projection
              {
                  'birthdate': 1,
                  'active': 1,
                  '_id': 0
              }
        )

for doc in cur:
    pp.pprint(doc)
# Out:
# {'birthdate': datetime.datetime(1977, 3, 2, 2, 20, 31), 'active': True}

# %% [markdown]
# ---
# **`$nor` operator**
#
# [$nor](https://docs.mongodb.com/manual/reference/operator/query/nor/#mongodb-query-op.-nor) matches those documents that fail to match all of specified conditions
#
# For example,
# * Retrive all documents that neither have `limit` as `7000` nor does it contain `products` `Brokerage` and `CurrencyService`

# %%
# NOR condition on multiple keys

cur = db.accounts.find(
                        {
                            # NOR operator
                            '$nor':[
                                        # limit 7000
                                        {
                                            'limit':7000
                                        },
                                        # products 'Brokerage' or 'CurrencyService'
                                        {
                                            'products':{
                                                            '$in':['Brokerage',
                                                                   'CurrencyService']
                                                        }
                                        }
                                  ]
                       },
                       {
                           'products':1,
                           'limit':1,
                           '_id':0
                       })

# Print all documents

for doc in cur:
    pp.pprint(doc)
# Out:
# {'limit': 9000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 9000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 9000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 9000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 8000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'limit': 9000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 8000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 3000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 9000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund', 'Commodity']}
# {'limit': 9000,
#  'products': ['InvestmentStock', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 9000, 'products': ['InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 8000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives', 'Commodity']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'Derivatives', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['Commodity', 'InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'Commodity', 'Derivatives', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Derivatives']}
# {'limit': 10000,
#  'products': ['Derivatives', 'InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 9000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['Derivatives', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'InvestmentFund']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Commodity', 'Derivatives']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock', 'Commodity']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentFund', 'InvestmentStock']}
# {'limit': 10000, 'products': ['InvestmentStock']}
# {'limit': 10000, 'products': ['Commodity', 'InvestmentStock']}

# %% [markdown]
# ---
# **`$nor` operator also returns those documents that do not contain either of queried fields**

# %%
# Count documents returned
db.accounts.find(
                    {
                        '$nor':[
                                    {
                                        'limit':7000
                                    },
                                    {
                                        'products':{
                                                        '$in':['Brokerage',
                                                               'CurrencyService']
                                                    }
                                    }
                              ]
                   },
                   {
                       'products':1,
                       'limit':1,
                       '_id':0
                   }).count()
# Out:
# /home/avadmin/.local/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# 560

# %% [markdown]
# ---
# **Insert a few sample documents where `limit` or `products` or both fields are missing**

# %%
# Insert sample documents
db.accounts.insert(
                   [
                        {
                            'account_id': 11111,
                        },
                        {
                            'account_id': 11112,
                            'limit':10000
                        },
                        {
                            'account_id': 11113,
                            'products': ['Derivatives']
                        }
                   ] )
# Out:
# /home/avadmin/.local/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   del sys.path[0]
# [ObjectId('60b23b57fd59298b0b20e34f'),
#  ObjectId('60b23b57fd59298b0b20e350'),
#  ObjectId('60b23b57fd59298b0b20e351')]

# %%
# Count documents returned
db.accounts.find(
                    {
                        '$nor':[
                                    {
                                        'limit':7000
                                    },
                                    {
                                        'products':{
                                                        '$in':['Brokerage',
                                                               'CurrencyService']
                                                    }
                                    }
                              ]
                   },
                   {
                       'products':1,
                       'limit':1,
                       '_id':0
                   }).count()
# Out:
# /home/avadmin/.local/lib/python3.7/site-packages/ipykernel_launcher.py:19: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# 563

# %% [markdown]
# ----
# **`$not` operator**
#
# [$not](https://docs.mongodb.com/manual/reference/operator/query/not/#-not)
# * operator returns logical NOT operation of specified query
# * It also returns documents that do not contain the queried field
#
# For example,
# * Retrieving documents where `limit` is not greater than 3000

# %%
# $not operator

cur = db.accounts.find(
                        # query expression
                        {
                            'limit': {
                                            '$not': {'$gt': 3000}
                                    }
                        },
                        # projection
                        {
                           'account_id':1,
                           'products':1,
                           'limit':1,
                           '_id':0,
                        })

# Print all documents

for doc in cur:
    pp.pprint(doc)
# Out:
# {'account_id': 417993,
#  'limit': 3000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'account_id': 113123,
#  'limit': 3000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'account_id': 11111}
# {'account_id': 11113, 'products': ['Derivatives']}

# %%
# Using comparison operator

cur = db.accounts.find(
                        # query expression
                        {
                            'limit': {'$lte': 3000}
                        },
                        # projection
                        {
                           'account_id':1,
                           'products':1,
                           'limit':1,
                           '_id':0,
                        })

# Print all documents

for doc in cur:
    pp.pprint(doc)
# Out:
# {'account_id': 417993,
#  'limit': 3000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'account_id': 113123,
#  'limit': 3000,
#  'products': ['CurrencyService', 'InvestmentStock']}

# %%
# Delete sample documents
db.accounts.delete_one({'account_id':11111})
db.accounts.delete_one({'account_id':11112})
db.accounts.delete_one({'account_id':11113})

# %% [markdown]
# ----
# ---
# ## Question -
#
# Retrieve documents where `limit` is neither between 5000 and 9000, nor does `products` array contain `Derivatives` or `Commodity` products

# %%
# Question
cur = db.accounts.find(
                        # query expression
                        {
                            '$nor':[
                                        {
                                            # 5000<= limit <=9000
                                            '$and':[
                                                        {'limit': {'$gte': 5000}},
                                                        {'limit': {'$lte': 9000}},
                                                    ]
                                        },
                                       # products contains `Derivatives` or `Commodity`
                                        {
                                            'products': {
                                                            '$in':['Derivatives',
                                                                   'Commodity']
                                                        }
                                        }
                                    ]
                        }
                    )

for doc in cur:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816238f'),
#  'account_id': 674364,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162394'),
#  'account_id': 487188,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162395'),
#  'account_id': 910579,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162398'),
#  'account_id': 976027,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816239e'),
#  'account_id': 299072,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816239f'),
#  'account_id': 137994,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a0'),
#  'account_id': 572981,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a2'),
#  'account_id': 616040,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a4'),
#  'account_id': 212024,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a5'),
#  'account_id': 433811,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a6'),
#  'account_id': 353465,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623a7'),
#  'account_id': 464470,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ac'),
#  'account_id': 276528,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ad'),
#  'account_id': 383701,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b0'),
#  'account_id': 463155,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b1'),
#  'account_id': 729049,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623b9'),
#  'account_id': 775690,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ba'),
#  'account_id': 813016,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623bf'),
#  'account_id': 304914,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c3'),
#  'account_id': 358213,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c5'),
#  'account_id': 781775,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c6'),
#  'account_id': 375872,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623c9'),
#  'account_id': 228290,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623cc'),
#  'account_id': 719065,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d0'),
#  'account_id': 604732,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d1'),
#  'account_id': 914559,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d3'),
#  'account_id': 817222,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d6'),
#  'account_id': 87389,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d8'),
#  'account_id': 696619,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623d9'),
#  'account_id': 714727,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e6'),
#  'account_id': 853542,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e7'),
#  'account_id': 945232,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e8'),
#  'account_id': 278497,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623e9'),
#  'account_id': 878471,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623ea'),
#  'account_id': 720842,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f2'),
#  'account_id': 168924,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f3'),
#  'account_id': 858473,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f4'),
#  'account_id': 827843,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f7'),
#  'account_id': 299100,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623f8'),
#  'account_id': 166084,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623fb'),
#  'account_id': 126444,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581623fd'),
#  'account_id': 165706,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162402'),
#  'account_id': 422649,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162404'),
#  'account_id': 678107,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162409'),
#  'account_id': 159243,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816240c'),
#  'account_id': 329562,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816240e'),
#  'account_id': 516700,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162413'),
#  'account_id': 588722,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162414'),
#  'account_id': 261796,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241a'),
#  'account_id': 300405,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241b'),
#  'account_id': 59715,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241c'),
#  'account_id': 261248,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816241f'),
#  'account_id': 723307,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162422'),
#  'account_id': 255695,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162423'),
#  'account_id': 581161,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816242a'),
#  'account_id': 296866,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816242d'),
#  'account_id': 78388,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162432'),
#  'account_id': 842570,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162434'),
#  'account_id': 839727,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162437'),
#  'account_id': 347313,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162438'),
#  'account_id': 795909,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816243a'),
#  'account_id': 199962,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816243f'),
#  'account_id': 977774,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162441'),
#  'account_id': 904434,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162444'),
#  'account_id': 767808,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162445'),
#  'account_id': 647189,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162446'),
#  'account_id': 357510,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162447'),
#  'account_id': 348352,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162448'),
#  'account_id': 999137,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816244d'),
#  'account_id': 116508,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816244f'),
#  'account_id': 292314,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162451'),
#  'account_id': 226865,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162452'),
#  'account_id': 604215,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162457'),
#  'account_id': 951849,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162459'),
#  'account_id': 130514,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245b'),
#  'account_id': 346408,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245e'),
#  'account_id': 679236,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816245f'),
#  'account_id': 985280,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162461'),
#  'account_id': 839760,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162466'),
#  'account_id': 409325,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816246b'),
#  'account_id': 325377,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162470'),
#  'account_id': 156715,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162472'),
#  'account_id': 485390,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162476'),
#  'account_id': 455365,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'Brokerage',
#               'CurrencyService',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162477'),
#  'account_id': 244662,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162478'),
#  'account_id': 120472,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816247c'),
#  'account_id': 141597,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162480'),
#  'account_id': 456867,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162483'),
#  'account_id': 155111,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162484'),
#  'account_id': 969775,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162485'),
#  'account_id': 879238,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162486'),
#  'account_id': 199711,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162488'),
#  'account_id': 130717,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162489'),
#  'account_id': 59768,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816248a'),
#  'account_id': 55104,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816248c'),
#  'account_id': 677943,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162494'),
#  'account_id': 786406,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162496'),
#  'account_id': 327942,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162497'),
#  'account_id': 720370,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162498'),
#  'account_id': 358133,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249a'),
#  'account_id': 951500,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249b'),
#  'account_id': 162007,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816249f'),
#  'account_id': 630581,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a7'),
#  'account_id': 528224,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a8'),
#  'account_id': 931483,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624a9'),
#  'account_id': 771691,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624ab'),
#  'account_id': 923468,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624ae'),
#  'account_id': 359211,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b0'),
#  'account_id': 226641,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b3'),
#  'account_id': 185130,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b6'),
#  'account_id': 616602,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624b7'),
#  'account_id': 387877,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624bd'),
#  'account_id': 183400,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624c1'),
#  'account_id': 415928,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624c3'),
#  'account_id': 914197,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624c4'),
#  'account_id': 650995,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624c5'),
#  'account_id': 271186,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624c9'),
#  'account_id': 644474,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624cb'),
#  'account_id': 118003,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624cd'),
#  'account_id': 131885,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624d0'),
#  'account_id': 861706,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624d4'),
#  'account_id': 571880,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624d9'),
#  'account_id': 534789,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624da'),
#  'account_id': 131176,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624dc'),
#  'account_id': 122923,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624dd'),
#  'account_id': 859284,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624de'),
#  'account_id': 709294,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624e5'),
#  'account_id': 442724,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624e6'),
#  'account_id': 427384,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624e8'),
#  'account_id': 165279,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624f2'),
#  'account_id': 300735,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581624fa'),
#  'account_id': 542264,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162502'),
#  'account_id': 143720,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162503'),
#  'account_id': 285919,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162504'),
#  'account_id': 947160,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816250a'),
#  'account_id': 141237,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816250c'),
#  'account_id': 510332,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816250e'),
#  'account_id': 120548,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162512'),
#  'account_id': 671035,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162513'),
#  'account_id': 575454,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162516'),
#  'account_id': 921679,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162519'),
#  'account_id': 870933,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816251a'),
#  'account_id': 667833,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816251d'),
#  'account_id': 294632,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816251e'),
#  'account_id': 782383,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816251f'),
#  'account_id': 136139,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162522'),
#  'account_id': 674464,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162524'),
#  'account_id': 516709,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162525'),
#  'account_id': 855057,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162526'),
#  'account_id': 774823,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162528'),
#  'account_id': 473748,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816252c'),
#  'account_id': 287686,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162535'),
#  'account_id': 426688,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162539'),
#  'account_id': 964645,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816253c'),
#  'account_id': 707812,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816254a'),
#  'account_id': 130832,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816254e'),
#  'account_id': 230611,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162551'),
#  'account_id': 776263,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162552'),
#  'account_id': 568788,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162554'),
#  'account_id': 155224,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162558'),
#  'account_id': 203285,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816255d'),
#  'account_id': 598715,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162567'),
#  'account_id': 720436,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162568'),
#  'account_id': 442170,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816256e'),
#  'account_id': 87437,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162574'),
#  'account_id': 681468,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162577'),
#  'account_id': 681381,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816257c'),
#  'account_id': 163269,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162584'),
#  'account_id': 379691,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162588'),
#  'account_id': 604077,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816258c'),
#  'account_id': 882334,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816258f'),
#  'account_id': 745028,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162590'),
#  'account_id': 638191,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162591'),
#  'account_id': 558048,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162592'),
#  'account_id': 622628,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162599'),
#  'account_id': 930584,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816259c'),
#  'account_id': 764007,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816259e'),
#  'account_id': 833317,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816259f'),
#  'account_id': 358684,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625a0'),
#  'account_id': 57322,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625a1'),
#  'account_id': 428110,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625a2'),
#  'account_id': 466310,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625a3'),
#  'account_id': 845284,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625a9'),
#  'account_id': 591026,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625ac'),
#  'account_id': 453177,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625b2'),
#  'account_id': 497088,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625b3'),
#  'account_id': 183253,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625b6'),
#  'account_id': 175926,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625b9'),
#  'account_id': 910860,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625ba'),
#  'account_id': 628472,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625bd'),
#  'account_id': 345766,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625c3'),
#  'account_id': 828552,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625c5'),
#  'account_id': 632543,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625c8'),
#  'account_id': 902507,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625c9'),
#  'account_id': 447044,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625ca'),
#  'account_id': 372043,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625cc'),
#  'account_id': 369761,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625d1'),
#  'account_id': 271109,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625d2'),
#  'account_id': 601671,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625d3'),
#  'account_id': 343230,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625d4'),
#  'account_id': 158557,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625de'),
#  'account_id': 906796,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625df'),
#  'account_id': 292528,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625e0'),
#  'account_id': 84115,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625e2'),
#  'account_id': 811931,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625e3'),
#  'account_id': 784245,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625e8'),
#  'account_id': 968920,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625ec'),
#  'account_id': 944578,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625f0'),
#  'account_id': 950569,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625f1'),
#  'account_id': 640540,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625f2'),
#  'account_id': 871955,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625f3'),
#  'account_id': 303463,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625f4'),
#  'account_id': 981415,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625f5'),
#  'account_id': 391838,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625f6'),
#  'account_id': 129238,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625f9'),
#  'account_id': 103346,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581625fe'),
#  'account_id': 602560,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162601'),
#  'account_id': 898156,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162605'),
#  'account_id': 225602,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162608'),
#  'account_id': 155327,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816260c'),
#  'account_id': 429282,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162610'),
#  'account_id': 163788,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162612'),
#  'account_id': 238687,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162615'),
#  'account_id': 935023,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162616'),
#  'account_id': 207806,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816261a'),
#  'account_id': 391557,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816261d'),
#  'account_id': 867593,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162620'),
#  'account_id': 965514,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162621'),
#  'account_id': 654939,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162626'),
#  'account_id': 899684,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162629'),
#  'account_id': 419542,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816262b'),
#  'account_id': 351069,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162633'),
#  'account_id': 323481,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'Brokerage',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162634'),
#  'account_id': 916626,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162635'),
#  'account_id': 487210,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162636'),
#  'account_id': 126102,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162639'),
#  'account_id': 207715,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816263a'),
#  'account_id': 884552,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816263b'),
#  'account_id': 987387,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816263f'),
#  'account_id': 533756,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162641'),
#  'account_id': 565145,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162646'),
#  'account_id': 851226,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816264f'),
#  'account_id': 954254,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162655'),
#  'account_id': 896644,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162656'),
#  'account_id': 527223,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162659'),
#  'account_id': 253017,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162661'),
#  'account_id': 417993,
#  'limit': 3000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162663'),
#  'account_id': 446093,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162664'),
#  'account_id': 190959,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162666'),
#  'account_id': 141474,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162670'),
#  'account_id': 788012,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162671'),
#  'account_id': 987355,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162676'),
#  'account_id': 586861,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162679'),
#  'account_id': 467666,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816267b'),
#  'account_id': 216662,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816267e'),
#  'account_id': 118134,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'Brokerage',
#               'InvestmentStock',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162680'),
#  'account_id': 692070,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162683'),
#  'account_id': 642554,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162684'),
#  'account_id': 938988,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162688'),
#  'account_id': 122551,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816268d'),
#  'account_id': 683393,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816268f'),
#  'account_id': 623060,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162695'),
#  'account_id': 979789,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162699'),
#  'account_id': 733568,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816269b'),
#  'account_id': 807144,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816269c'),
#  'account_id': 995007,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626a0'),
#  'account_id': 668634,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626a2'),
#  'account_id': 297819,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626a6'),
#  'account_id': 150713,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'InvestmentStock',
#               'CurrencyService',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626a7'),
#  'account_id': 668857,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626a9'),
#  'account_id': 921272,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626ad'),
#  'account_id': 113123,
#  'limit': 3000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626b1'),
#  'account_id': 917549,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626b2'),
#  'account_id': 469980,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626b4'),
#  'account_id': 725209,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626b5'),
#  'account_id': 738462,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626b7'),
#  'account_id': 436090,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626b8'),
#  'account_id': 700387,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626bc'),
#  'account_id': 305286,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626c1'),
#  'account_id': 768875,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626c2'),
#  'account_id': 105134,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626c6'),
#  'account_id': 933061,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626c8'),
#  'account_id': 209755,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626c9'),
#  'account_id': 377488,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626ca'),
#  'account_id': 351905,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626ce'),
#  'account_id': 937618,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626d2'),
#  'account_id': 188293,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626d4'),
#  'account_id': 179746,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626d9'),
#  'account_id': 109478,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626da'),
#  'account_id': 730824,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626db'),
#  'account_id': 611998,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626dc'),
#  'account_id': 258443,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626df'),
#  'account_id': 182103,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626e0'),
#  'account_id': 435187,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626e4'),
#  'account_id': 587875,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626e9'),
#  'account_id': 300879,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626f0'),
#  'account_id': 180092,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626f1'),
#  'account_id': 830030,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626f4'),
#  'account_id': 518420,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581626f6'),
#  'account_id': 809938,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162702'),
#  'account_id': 390745,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162703'),
#  'account_id': 123689,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162704'),
#  'account_id': 182387,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162705'),
#  'account_id': 618428,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816270d'),
#  'account_id': 823026,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816270e'),
#  'account_id': 906290,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816270f'),
#  'account_id': 777962,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162711'),
#  'account_id': 897284,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816271a'),
#  'account_id': 905866,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816271b'),
#  'account_id': 374953,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816271c'),
#  'account_id': 385025,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816271d'),
#  'account_id': 323373,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816271e'),
#  'account_id': 214649,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816271f'),
#  'account_id': 849780,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162721'),
#  'account_id': 676471,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162722'),
#  'account_id': 532811,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162723'),
#  'account_id': 657111,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162726'),
#  'account_id': 265053,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'InvestmentStock',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816272f'),
#  'account_id': 623937,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'InvestmentFund',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162730'),
#  'account_id': 798739,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162733'),
#  'account_id': 591354,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162734'),
#  'account_id': 54685,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162736'),
#  'account_id': 304730,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162739'),
#  'account_id': 577112,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816273d'),
#  'account_id': 180580,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162743'),
#  'account_id': 917475,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'CurrencyService',
#               'InvestmentFund',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162745'),
#  'account_id': 946196,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162748'),
#  'account_id': 610738,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816274e'),
#  'account_id': 894281,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'CurrencyService']}
# ...
#  'account_id': 759185,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162925'),
#  'account_id': 406971,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162929'),
#  'account_id': 731178,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816292a'),
#  'account_id': 994208,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816292b'),
#  'account_id': 996840,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816292d'),
#  'account_id': 492843,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816292f'),
#  'account_id': 363315,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162932'),
#  'account_id': 126092,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162936'),
#  'account_id': 193228,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162937'),
#  'account_id': 242287,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816293a'),
#  'account_id': 572301,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentStock',
#               'Brokerage',
#               'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816293b'),
#  'account_id': 565989,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816293c'),
#  'account_id': 147641,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816293e'),
#  'account_id': 287485,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816293f'),
#  'account_id': 372442,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162941'),
#  'account_id': 741535,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162944'),
#  'account_id': 609817,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162945'),
#  'account_id': 591359,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162946'),
#  'account_id': 689984,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162947'),
#  'account_id': 460206,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816294a'),
#  'account_id': 580317,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816294b'),
#  'account_id': 279899,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816294e'),
#  'account_id': 611229,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162951'),
#  'account_id': 89646,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162957'),
#  'account_id': 355301,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162959'),
#  'account_id': 255267,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816295a'),
#  'account_id': 624318,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816295c'),
#  'account_id': 600800,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'CurrencyService',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816295f'),
#  'account_id': 730522,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162960'),
#  'account_id': 826984,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162965'),
#  'account_id': 134905,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162966'),
#  'account_id': 229899,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162969'),
#  'account_id': 265264,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816296c'),
#  'account_id': 308215,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162972'),
#  'account_id': 297499,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162980'),
#  'account_id': 51617,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162984'),
#  'account_id': 67224,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162985'),
#  'account_id': 884611,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162986'),
#  'account_id': 947606,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162988'),
#  'account_id': 537158,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816298b'),
#  'account_id': 335665,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816298c'),
#  'account_id': 96431,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816298e'),
#  'account_id': 164260,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816298f'),
#  'account_id': 429495,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162990'),
#  'account_id': 130610,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162993'),
#  'account_id': 388334,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162996'),
#  'account_id': 317449,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee5816299d'),
#  'account_id': 750828,
#  'limit': 10000,
#  'products': ['CurrencyService', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629a4'),
#  'account_id': 95914,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629a7'),
#  'account_id': 920666,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629a8'),
#  'account_id': 122908,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629aa'),
#  'account_id': 531370,
#  'limit': 10000,
#  'products': ['Brokerage', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629ad'),
#  'account_id': 568852,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629b2'),
#  'account_id': 481754,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629b4'),
#  'account_id': 654392,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629b5'),
#  'account_id': 153377,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629b9'),
#  'account_id': 540237,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629ba'),
#  'account_id': 743205,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629bc'),
#  'account_id': 875074,
#  'limit': 10000,
#  'products': ['InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629bd'),
#  'account_id': 181984,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629be'),
#  'account_id': 690308,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629bf'),
#  'account_id': 201361,
#  'limit': 10000,
#  'products': ['Brokerage',
#               'InvestmentFund',
#               'CurrencyService',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629c1'),
#  'account_id': 921629,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629c4'),
#  'account_id': 82467,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629c5'),
#  'account_id': 992584,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629c9'),
#  'account_id': 700455,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629cf'),
#  'account_id': 892096,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629d2'),
#  'account_id': 97487,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629d5'),
#  'account_id': 55473,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629d6'),
#  'account_id': 835955,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629d9'),
#  'account_id': 826367,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629dd'),
#  'account_id': 678293,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629e3'),
#  'account_id': 352008,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629e4'),
#  'account_id': 360322,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629e8'),
#  'account_id': 59275,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629e9'),
#  'account_id': 365969,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629eb'),
#  'account_id': 486766,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629ef'),
#  'account_id': 493235,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'InvestmentFund',
#               'CurrencyService',
#               'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629f1'),
#  'account_id': 150321,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629f3'),
#  'account_id': 187397,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629fa'),
#  'account_id': 933986,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629fd'),
#  'account_id': 363061,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'InvestmentFund',
#               'Brokerage',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629fe'),
#  'account_id': 323327,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee581629ff'),
#  'account_id': 462180,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a01'),
#  'account_id': 413410,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a07'),
#  'account_id': 120917,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a08'),
#  'account_id': 272399,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a0d'),
#  'account_id': 73934,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a15'),
#  'account_id': 249810,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a1c'),
#  'account_id': 825051,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a1e'),
#  'account_id': 232492,
#  'limit': 10000,
#  'products': ['InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a23'),
#  'account_id': 171129,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a28'),
#  'account_id': 657218,
#  'limit': 10000,
#  'products': ['CurrencyService',
#               'Brokerage',
#               'InvestmentFund',
#               'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a29'),
#  'account_id': 380304,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a2b'),
#  'account_id': 211212,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'Brokerage']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a35'),
#  'account_id': 223693,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a37'),
#  'account_id': 509384,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a43'),
#  'account_id': 109710,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a44'),
#  'account_id': 669413,
#  'limit': 10000,
#  'products': ['InvestmentStock',
#               'Brokerage',
#               'InvestmentFund',
#               'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a46'),
#  'account_id': 916567,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a4f'),
#  'account_id': 912504,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a50'),
#  'account_id': 406478,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a51'),
#  'account_id': 496316,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a55'),
#  'account_id': 996624,
#  'limit': 10000,
#  'products': ['CurrencyService', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a57'),
#  'account_id': 551774,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a58'),
#  'account_id': 225728,
#  'limit': 10000,
#  'products': ['InvestmentStock', 'CurrencyService']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a59'),
#  'account_id': 771935,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5b'),
#  'account_id': 635650,
#  'limit': 10000,
#  'products': ['Brokerage', 'InvestmentStock', 'InvestmentFund']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5e'),
#  'account_id': 684319,
#  'limit': 10000,
#  'products': ['InvestmentFund', 'InvestmentStock']}
# {'_id': ObjectId('5ca4bbc7a2dd94ee58162a5f'),
#  'account_id': 351063,
#  'limit': 10000,
#  'products': ['InvestmentStock']}

# %% [markdown]
# ---
# ### Exercise 1 -
#
# From the `customers` collection retrieve documents where either the `birthdate` is after (1990,1,1) or the `active` field is True.
#
# ---

# %% [markdown]
# ### Exercise 2 -
#
# Look for documents where
#
# - `limit` is either <= 7000 or `limit` is >= 9000
#
# - and `products` is `['InvestmentStock', 'InvestmentFund']`
#
# ---
