# %% [markdown]
# # `Connecting to local MongoDB server using PyMongo`

# %% [markdown]
# ### `collections to restore from Atlas_sample_data`

# %% [markdown]
# * `!` mark tells its a terminal command being executed in shell

# %%
# !/Users/mvon/mongodb/bin/mongorestore  /Users/mvon/Desktop/sample_data
# Out:
# 2021-08-03T17:24:44.453+0530	preparing collections to restore from
# 2021-08-03T17:24:44.453+0530	don't know what to do with file "/Users/mvon/Desktop/AV/W37-MongoDB/sample_data/.DS_Store", skipping...
# 2021-08-03T17:24:44.454+0530	restoring to existing collection sample_geospatial.shipwrecks without dropping
# 2021-08-03T17:24:44.454+0530	reading metadata for sample_geospatial.shipwrecks from /Users/mvon/Desktop/AV/W37-MongoDB/sample_data/sample_geospatial/shipwrecks.metadata.json
# 2021-08-03T17:24:44.455+0530	restoring sample_geospatial.shipwrecks from /Users/mvon/Desktop/AV/W37-MongoDB/sample_data/sample_geospatial/shipwrecks.bson
# 2021-08-03T17:24:44.649+0530	continuing through error: E11000 duplicate key error collection: sample_geospatial.shipwrecks index: _id_ dup key: { _id: ObjectId('578f6fa2df35c7fbdbaed8c4') }
# ...

# %%
import pymongo

# %%
# Connect to local MongoDB server

client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# Client
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
